# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **Read csv file into dataframe**

# %%
data = pd.read_csv('NYPD_Shooting_Incident_Data.csv', na_values = ["(null)"]) #change (null) values to Na
data.shape
data
# Out:
#      INCIDENT_KEY  OCCUR_DATE OCCUR_TIME       BORO LOC_OF_OCCUR_DESC  \
# 0       308408221  06/20/2025   19:06:00     QUEENS           OUTSIDE
# 1       306062049  05/08/2025   00:25:00      BRONX           OUTSIDE
# 2       312202110  09/01/2025   19:34:00      BRONX           OUTSIDE
# 3       312957372  09/15/2025   17:32:00  MANHATTAN           OUTSIDE
# 4       311949658  08/26/2025   15:30:00      BRONX           OUTSIDE
# ..            ...         ...        ...        ...               ...
# 764     306394911  05/14/2025   05:56:00   BROOKLYN           OUTSIDE
# 765     305404405  04/26/2025   20:54:00     QUEENS           OUTSIDE
# 766     311327863  08/17/2025   03:27:00   BROOKLYN           OUTSIDE
# 767     311756929  08/23/2025   17:26:00      BRONX           OUTSIDE
# 768     299956934  01/23/2025   23:43:00      BRONX           OUTSIDE
#
#      PRECINCT  JURISDICTION_CODE LOC_CLASSFCTN_DESC  \
# 0         104                  0             STREET
# ...

# %% [markdown]
# **Check for null values**

# %%
data.isna().sum()
# Out:
# INCIDENT_KEY                  0
# OCCUR_DATE                    0
# OCCUR_TIME                    0
# BORO                          0
# LOC_OF_OCCUR_DESC             0
# PRECINCT                      0
# JURISDICTION_CODE             0
# LOC_CLASSFCTN_DESC            2
# LOCATION_DESC               514
# STATISTICAL_MURDER_FLAG       0
# PERP_AGE_GROUP              263
# PERP_SEX                    263
# PERP_RACE                   263
# VIC_AGE_GROUP                 0
# VIC_SEX                       0
# VIC_RACE                      0
# X_COORD_CD                    0
# Y_COORD_CD                    0
# Latitude                      0
# Longitude                     0
# New Georeferenced Column      0
# dtype: int64

# %% [markdown]
# **drop unnecessary column**

# %%
cleaned_data = data.drop(columns = ['LOCATION_DESC','PERP_AGE_GROUP', 'PERP_SEX','PERP_RACE','X_COORD_CD', 'Y_COORD_CD', 'New Georeferenced Column', 'STATISTICAL_MURDER_FLAG'])
cleaned_data
# Out:
#      INCIDENT_KEY  OCCUR_DATE OCCUR_TIME       BORO LOC_OF_OCCUR_DESC  \
# 0       308408221  06/20/2025   19:06:00     QUEENS           OUTSIDE
# 1       306062049  05/08/2025   00:25:00      BRONX           OUTSIDE
# 2       312202110  09/01/2025   19:34:00      BRONX           OUTSIDE
# 3       312957372  09/15/2025   17:32:00  MANHATTAN           OUTSIDE
# 4       311949658  08/26/2025   15:30:00      BRONX           OUTSIDE
# ..            ...         ...        ...        ...               ...
# 764     306394911  05/14/2025   05:56:00   BROOKLYN           OUTSIDE
# 765     305404405  04/26/2025   20:54:00     QUEENS           OUTSIDE
# 766     311327863  08/17/2025   03:27:00   BROOKLYN           OUTSIDE
# 767     311756929  08/23/2025   17:26:00      BRONX           OUTSIDE
# 768     299956934  01/23/2025   23:43:00      BRONX           OUTSIDE
#
#      PRECINCT  JURISDICTION_CODE LOC_CLASSFCTN_DESC VIC_AGE_GROUP VIC_SEX  \
# ...

# %%
cleaned_data.to_csv("cleaned_shooting_incident_3.csv", index=False)

# %%
#using occur time to add column of morning/noon/night when shooting occur
#def time_category(time):
    #return int(time.split(':')[0])
#time = cleaned_data['OCCUR_TIME'].apply(time_category)

# %%
# analyze how safe is each area (by boro) - at certain time in day, location, victim's age/sex/race
